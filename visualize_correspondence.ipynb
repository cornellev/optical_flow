# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np


from sub_harris import detect, displayCorners
from plot_matches import drawPercent
# Out:
# A
# JKKJKJJKKJLLJLJLJLLJKLJLJK

# %%
# visualize original images
img1 = cv2.imread('resources/triangle1.jpg', cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img2 = cv2.imread('resources/triangle2.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

f, axarr = plt.subplots(1, 2)
axarr[0].imshow(img1)
axarr[1].imshow(img2)

# %%
s, k = 2, 5
f, axarr = plt.subplots(1, 2)
img1_norm = img1.astype(np.float32)/255.
img2_norm = img2.astype(np.float32)/255.
grayImage1 = cv2.cvtColor(img1_norm, cv2.COLOR_BGR2GRAY)
grayImage2 = cv2.cvtColor(img2_norm, cv2.COLOR_BGR2GRAY)
h, w = grayImage1.shape
thres = min(h,w) // 1

corners1 = detect(grayImage1, s, k, thres).tolist()
corners2 = detect(grayImage2, s, k, thres).tolist()

print(corners1)

axarr[0].imshow(displayCorners(grayImage1, s, k, thres, (0, 255, 0)))
axarr[1].imshow(displayCorners(grayImage2, s, k, thres, (0, 255, 0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[94.0, 40.0, 140.94796752929688, 1.5286337884390377e-07], [92.0, 47.0, 79.94786834716797, 0.029281415045261383], [81.0, 48.0, 142.77194213867188, 8.386090399881141e-08], [101.0, 48.0, 52.22929000854492, 2.4962977462905656e-08], [83.0, 53.0, -26.921457290649414, 1.7044362721208017e-06], [93.0, 54.0, 54.950260162353516, 6.409959496522788e-07], [103.0, 54.0, 111.1990966796875, 6.391731943722334e-08], [75.0, 56.0, 125.96051025390625, 2.226547302086601e-08], [95.0, 60.0, 51.41914367675781, 3.6945448922409696e-09], [102.0, 60.0, -97.1438980102539, 4.282831014279509e-07], [76.0, 61.0, -31.84885597229004, 2.4215998450927145e-07], [64.0, 64.0, 0.0, 2.3666175685832513e-09], [81.0, 64.0, 107.30448913574219, 6.670688890153542e-07], [111.0, 64.0, 150.85389709472656, 1.5139150377763144e-08], [105.0, 65.0, 94.64946746826172, 8.097353010327879e-09], [72.0, 66.0, -37.257442474365234, 1.6455135209980654e-07], [78.0, 68.0, 22.161752700805664, 1.925323203977314e-06], [98.0, 68.0, 41.12577438354492, 2.725203387399233e-07], [68.0, 71.0, 102.30333709716797, 1.3780883136860211e-06], [101.0, 72.0, -162.5168914794922, 3.0282095053735247e-07], [111.0, 73.0, -113.80426025390625, 1.216372140788735e-07], [70.0, 77.0, -23.550029754638672, 1.6009089449653402e-05], [110.0, 77.0, -121.25032806396484, 1.8581937410999672e-07], [77.0, 79.0, 122.9699935913086, 2.47917153473054e-08], [56.0, 80.0, 53.66705322265625, 1.545965346849698e-07], [60.0, 81.0, 141.9492645263672, 7.07447668446548e-07], [105.0, 81.0, 70.68214416503906, 4.895708229923912e-07], [66.0, 82.0, -39.40902328491211, 7.719085260760039e-06], [108.0, 87.0, 61.40890121459961, 1.0998794550687307e-06], [48.0, 88.0, 49.625022888183594, 1.1977471459090339e-08], [54.0, 88.0, 138.04331970214844, 3.261655763253657e-07], [118.0, 88.0, 115.18132781982422, 1.9111551807782234e-07], [60.0, 91.0, -68.30586242675781, 4.488907507038675e-06], [109.0, 92.0, 56.37559127807617, 3.1864263405623205e-07], [50.0, 93.0, -38.378196716308594, 3.576632678914393e-08], [51.0, 98.0, -30.02569007873535, 0.038645654916763306], [113.0, 98.0, -19.50535011291504, 8.519405696461035e-07], [73.0, 101.0, 44.744476318359375, 2.0235438569216058e-06], [115.0, 102.0, 72.54718017578125, 6.240579750738107e-06], [55.0, 103.0, -134.92037963867188, 4.559532484904594e-08], [88.0, 103.0, 64.0453872680664, 4.129836028710088e-09], [122.0, 104.0, 63.307559967041016, 3.706568918460107e-07], [64.0, 105.0, 0.0, 2.255650777271967e-09], [99.0, 106.0, -88.60649108886719, 5.783164880313052e-08], [75.0, 107.0, -156.6109161376953, 6.245453221254138e-08], [107.0, 108.0, -166.55087280273438, 1.0791723070724402e-06], [85.0, 109.0, -149.54026794433594, 6.737678859281004e-08], [115.0, 110.0, -173.6783905029297, 8.195964255719446e-06], [122.0, 113.0, -164.40919494628906, 0.036420829594135284], [107.0, 114.0, 51.53934860229492, 4.863768481300212e-07], [113.0, 115.0, -159.42295837402344, 6.79676531945006e-07]]

# %%
# 79.9% matched and the threshold is 10^(-2).
vis = drawPercent(79.9, img1, img2, -2, corners1, corners2)
plt.figure(figsize=(15, 20))
plt.axis('off')
plt.imshow(vis)

# %%
# visualize original images
img1 = cv2.imread('resources/yosemite/yosemite1.jpg', cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img2 = cv2.imread('resources/yosemite/yosemite2.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

f, axarr = plt.subplots(1, 2)
axarr[0].imshow(img1)
axarr[1].imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_88649/1066526544.py in <module>
#       1 # visualize original images
#       2 img1 = cv2.imread('resources/yosemite/yosemite1.jpg', cv2.IMREAD_COLOR)
# ----> 3 img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
#       4
#       5 img2 = cv2.imread('resources/yosemite/yosemite2.jpg', cv2.IMREAD_COLOR)
#
# error: OpenCV(3.4.2) /tmp/build/80754af9/opencv-suite_1535558553474/work/modules/imgproc/src/color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'CvtHelper'

# %%
# compute Harris corner detection and MOPS for img1
img1_norm = img1.astype(np.float32)
img1_norm /= 255.
grayImage1 = cv2.cvtColor(img1_norm, cv2.COLOR_BGR2GRAY)
corners1 = detect(grayImage1, 2, 5)


#compute Harris corner detection and MOPS for img2
img2_norm = img2.astype(np.float32)
img2_norm /= 255.
grayImage2 = cv2.cvtColor(img2_norm, cv2.COLOR_BGR2GRAY)
corners2 = detect(grayImage1, 2, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_84612/1097359115.py in <module>
#       3 img1_norm /= 255.
#       4 grayImage1 = cv2.cvtColor(img1_norm, cv2.COLOR_BGR2GRAY)
# ----> 5 corners1 = detect(grayImage1, 2, 5)
#       6
#       7
#
# TypeError: detect() missing 1 required positional argument: 'thres'

# %%
# 9.9% matched and the threshold is 10^(-.8). 
vis = drawPercent(9.9, img1, img2, -.8, corners1, corners2)
plt.figure(figsize=(15, 20))
plt.axis('off')
plt.imshow(vis)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_88649/1083456465.py in <module>
#       1 # 9.9% matched and the threshold is 10^(-.8).
# ----> 2 vis = drawPercent(9.9, img1, img2, -.8, corners1, corners2)
#       3 plt.figure(figsize=(15, 20))
#       4 plt.axis('off')
#       5 plt.imshow(vis)
#
# ~/optical_flow/plot_matches.py in drawPercent(percent, img1, img2, threshold_x, kpts1, kpts2)
#      60     thresholdedKeypoints1 = thresholdKeyPoints(kpts1, 10 ** threshold_x)
#      61     thresholdedKeypoints2 = thresholdKeyPoints(kpts2, 10 ** threshold_x)
# ---> 62     mopsDesc1 = computeMOPSDescriptors(img1, thresholdedKeypoints1)
#      63     mopsDesc2 = computeMOPSDescriptors(img2, thresholdedKeypoints2)
#      64
#
# ~/optical_flow/sub_harris.py in computeMOPSDescriptors(image, features)
#     273                 and W is the window size
#     274     """
# --> 275     image = image.astype(np.float32)
#     276     image /= 255.
#     277     # This image represents the window around the feature you need to
#
# AttributeError: 'NoneType' object has no attribute 'astype'

# %%
# visualize original images
img1 = cv2.imread('resources/img1.png', cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img2 = cv2.imread('resources/img2.png', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

f, axarr = plt.subplots(1, 2)
axarr[0].imshow(img1)
axarr[1].imshow(img2)

# %%
s, k = 2, 5
f, axarr = plt.subplots(1, 2)
grayImage1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
grayImage2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
# print(grayImage1)
h, w = grayImage1.shape
thres = min(h,w) // 1

corners1 = detect(grayImage1, s, k, thres).tolist()
corners2 = detect(grayImage2, s, k, thres).tolist()
print(corners1)
print(np.max(np.array(corners1)[:,0]))

corners1 = displayCorners(grayImage1, s, k, thres, (255, 0, 0))
corners2 = displayCorners(grayImage2, s, k, thres, (255, 0, 0))

axarr[0].imshow(corners1)
axarr[1].imshow(corners2)
# Out:
# 2661
# 399.0

# %%
# compute Harris corner detection and MOPS for img1
img1_norm = img1.astype(np.float32)
img1_norm /= 255.
thres = min(h,w) // 2
grayImage1 = cv2.cvtColor(img1_norm, cv2.COLOR_BGR2GRAY)
corners1 = detect(grayImage1, 2, 5, thres)


#compute Harris corner detection and MOPS for img2
img2_norm = img2.astype(np.float32)
img2_norm /= 255.
grayImage2 = cv2.cvtColor(img2_norm, cv2.COLOR_BGR2GRAY)
corners2 = detect(grayImage2, 2, 5, thres)

# %%
# 5.6% matched and the threshold is 10^(-.8). 
vis = drawPercent(5.6, img1, img2, -.8, corners1, corners2)
plt.figure(figsize=(15, 20))
plt.axis('off')
plt.imshow(vis)

# %%
# visualize original images
img1 = cv2.imread('resources/heart1.jpg', cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img2 = cv2.imread('resources/heart2.jpg', cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

f, axarr = plt.subplots(1, 2)
axarr[0].imshow(img1)
axarr[1].imshow(img2)

# %%
# compute Harris corner detection and MOPS for img1
img1_norm = img1.astype(np.float32)
img1_norm /= 255.
grayImage1 = cv2.cvtColor(img1_norm, cv2.COLOR_BGR2GRAY)
(harrisImg1, orientationImg1) = computeHarrisValues(grayImage1)
corners1 = detect(harrisImg1,orientationImg1)


#compute Harris corner detection and MOPS for img2
img2_norm = img2.astype(np.float32)
img2_norm /= 255.
grayImage2 = cv2.cvtColor(img2_norm, cv2.COLOR_BGR2GRAY)
(harrisImg2, orientationImg2) = computeHarrisValues(grayImage2)
corners2 = detect(harrisImg2,orientationImg2)

# %%
# 2.6% matched and the threshold is 10^(-5).
vis = drawPercent(2.6, img1, img2, -5, corners1, corners2)
plt.figure(figsize=(15, 20))
plt.axis('off')
plt.imshow(vis)
